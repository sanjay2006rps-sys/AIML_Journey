# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjay2006rps-sys/AIML_Journey/blob/main/Module_12_Exception_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    number = int(input("Enter a number: "))
    print("You entered:", number)

except ValueError:
    print("Please enter only numbers.")
# Out:
# Enter a number: dhsbh
# Please enter only numbers.

# %%
try:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))

    print("Result =", a / b)

except ZeroDivisionError:
    print("Cannot divide by zero.")

except ValueError:
    print("Invalid number.")
# Out:
# Enter first number: 4352
# Enter second number: 653625
# Result = 0.006658252055842417

# %%
try:
    age = int(input("Enter age: "))

except ValueError:
    print("Invalid age.")

else:
    print("Age accepted.")
# Out:
# Enter age: 67
# Age accepted.

# %%
try:
    x = int(input())

except ValueError:
    print("Wrong input")

finally:
    print("Program Finished")
# Out:
# gfhdshs
# Wrong input
# Program Finished

# %%
def withdraw(balance, amount):

    if amount > balance:
        raise ValueError("Insufficient Balance")

    return balance - amount


try:
    balance = 5000

    amount = int(input("Enter amount: "))

    balance = withdraw(balance, amount)

    print(balance)

except ValueError as e:
    print(e)
# Out:
# Enter amount: 5000
# 0

# %%
with open("student.txt", "w") as file:
    file.write("Hello AI Engineer")
with open("student.txt", "r") as file:
    print(file.read())
# Out:
# Hello AI Engineer

# %%
try:
    with open("abc.txt") as file:
        print(file.read())

except FileNotFoundError:
    print("File Not Found")
# Out:
# File Not Found

# %%
class BankAccount:
    ...

# %%
def menu():
    ...

# %%
while True:
    ...
